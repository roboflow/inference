# %% [markdown]
# # CLIP Classify Content of Video
#
# ---
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/roboflow/notebooks/blob/main/notebooks/vector-analysis-with-sklearn-and-bokeh.ipynb)
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/vector-analysis)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/notebooks)
#
# Click the Open in Colab button to run the cookbook on Google Colab.
#
# **Let's begin!**

# %% [markdown]
# # Install required packages
# In this cookbook, we'll leverage two Python packages - `opencv` and `supervision`

# %%
# !pip install supervision opencv-python

# %% [markdown]
# ## Imports & Configure Roboflow Inference Server

# %%
import requests
import base64
from PIL import Image
from io import BytesIO
import os
import supervision as sv
from tqdm import tqdm
from supervision import get_video_frames_generator
import time

INFERENCE_ENDPOINT = "https://infer.roboflow.com"
API_KEY = "YOUR_API_KEY"
VIDEO = "VIDEO_PATH"

# %% [markdown]
# ## Prompt List for CLIP similarity function

# %%
#Prompt list to evaluate similarity between each image and each prompt. If something else is selected, then we ignore the caption
#change this to your desired prompt list
prompt_list = [['action video game shooting xbox','Drake rapper music','soccer game ball',
                'marvel combic book','beyonce','Church pope praying',
                'Mcdonalds French Fries',"something else"]]

# %% [markdown]
# ## CLIP Endpoint Compare Frame & Prompt List Similarity

# %%
def classify_image(image: str, prompt: str) -> dict:
    
    image_data = Image.fromarray(image)

    buffer = BytesIO()
    image_data.save(buffer, format="JPEG")
    image_data = base64.b64encode(buffer.getvalue()).decode("utf-8")

    payload = {
        "api_key": API_KEY,
        "subject": {
            "type": "base64",
            "value": image_data
        },
        "prompt": prompt,
    }

    data = requests.post(INFERENCE_ENDPOINT + "/clip/compare?api_key=" + API_KEY, json=payload)

    response = data.json()
    #print(response["similarity"])
    sim = response["similarity"]

    highest_prediction = 0
    highest_prediction_index = 0

    for i, prediction in enumerate(response["similarity"]):
        if prediction > highest_prediction:
            highest_prediction = prediction
            highest_prediction_index = i

    return prompt[highest_prediction_index], sim[highest_prediction_index]

# %% [markdown]
# # Process Video & Return Most Similar Prompt to Frame

# %%
def process_video_frames(video_path, prompt_list, total_frames=160, total_seconds=80, stride_length=30,max_retries):
    if not os.path.exists(video_path):
        print(f"The specified video file '{video_path}' does not exist.")
        return

    frames_per_second = total_frames / total_seconds
    frame_dict = {}

    for frame_index, frame in enumerate(sv.get_video_frames_generator(source_path=video_path, stride=stride_length, start=0)):
        frame_second = frame_index * (1 / frames_per_second)
        frame_key = f"Frame {frame_index}: {frame_second:.2f} seconds"
        frame_dict[frame_key] = []

        print(frame_key)
        retries = 0

        for prompt in prompt_list:
            try: 
                label, similarity = classify_image(frame)
                if label != "something else":
                    print('label found')
                    frame_dict[frame_key].append({label: similarity})
                    print('\n')

            except Exception as e:
                retries += 1
                print(f"Error: {e}")
                print(f"Retrying... (Attempt {retries}/{max_retries})")

                if retries >= max_retries:
                    print("Max retries exceeded. Skipping frame.")
                    break

    return frame_dict

# Example usage:
max_retries = 4
prompt_list = prompt_list
frame_results = process_video_frames(VIDEO, prompt_list,max_retries)

# %%
#print(os.path.exists(VIDEO))

max_retries = 4

total_frames = 160
total_seconds = 80
stride_length = 30
frames_per_second = total_frames / total_seconds
frame_dict = {}
num_frames = 0
for frame_index,frame in enumerate(sv.get_video_frames_generator(source_path=VIDEO,stride=stride_length,start =0)):
    frame_second = frame_index * (1 / frames_per_second)
    frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"] = []
    if frame_index < 200:
        print(f"Frame {frame_index}: {frame_second:.2f} seconds")
        retries = 0
        for prompt in prompt_list:
            try: 
                label,similarity = classify_image(frame)
                if label != "something else":
                    print('label found')
                    frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"].append({label:similarity})
                    #frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"].append(similarity)
                    
                    print('\n')
            except Exception as e:
                retries+=1
                print(f"Error: {e}")
                print(f"Retrying... (Attempt {retries + 1}/{max_retries})")
                retries += 1
                time.sleep(1)  # Wait for a short period before retrying
# Out:
# Frame 0: 0.00 seconds
# label found
#
#
# Frame 1: 0.50 seconds
# label found
#
#
# Frame 2: 1.00 seconds
# label found
#
#
# Frame 3: 1.50 seconds
# label found
#
#
# Frame 4: 2.00 seconds
# label found
#
#
# Frame 5: 2.50 seconds
# label found
#
#
# Frame 6: 3.00 seconds
# label found
#
#
# Frame 7: 3.50 seconds
# label found
#
#
# Frame 8: 4.00 seconds
# label found
#
#
# Frame 9: 4.50 seconds
# label found
#
#
# Frame 10: 5.00 seconds
# label found
#
#
# Frame 11: 5.50 seconds
# label found
#
#
# Frame 12: 6.00 seconds
# label found
#
#
# Frame 13: 6.50 seconds
# label found
#
#
# Frame 14: 7.00 seconds
# label found
#
#
# Frame 15: 7.50 seconds
# label found
#
#
# Frame 16: 8.00 seconds
# label found
#
#
# Frame 17: 8.50 seconds
# label found
#
#
# Frame 18: 9.00 seconds
# label found
#
#
# Frame 19: 9.50 seconds
# label found
#
#
# Frame 20: 10.00 seconds
# label found
#
#
# Frame 21: 10.50 seconds
# label found
#
#
# Frame 22: 11.00 seconds
# label found
#
#
# Frame 23: 11.50 seconds
# label found
#
#
# Frame 24: 12.00 seconds
# label found
#
#
# Frame 25: 12.50 seconds
# label found
#
#
# Frame 26: 13.00 seconds
# label found
#
#
# Frame 27: 13.50 seconds
# label found
#
#
# Frame 28: 14.00 seconds
# label found
#
#
# Frame 29: 14.50 seconds
# label found
#
#
# Frame 30: 15.00 seconds
# label found
#
#
# Frame 31: 15.50 seconds
# label found
#
#
# Frame 32: 16.00 seconds
# label found
#
#
# Frame 33: 16.50 seconds
# label found
#
#
# Frame 34: 17.00 seconds
# label found
#
#
# Frame 35: 17.50 seconds
# label found
#
#
# Frame 36: 18.00 seconds
# label found
#
#
# Frame 37: 18.50 seconds
# label found
#
#
# Frame 38: 19.00 seconds
# label found
#
#
# Frame 39: 19.50 seconds
# label found
#
#
# Frame 40: 20.00 seconds
# label found
#
#
# Frame 41: 20.50 seconds
# label found
#
#
# Frame 42: 21.00 seconds
# label found
#
#
# Frame 43: 21.50 seconds
# label found
#
#
# Frame 44: 22.00 seconds
# label found
#
#
# Frame 45: 22.50 seconds
# label found
#
#
# Frame 46: 23.00 seconds
# label found
#
#
# Frame 47: 23.50 seconds
# label found
#
#
# Frame 48: 24.00 seconds
# label found
#
#
# Frame 49: 24.50 seconds
# label found
#
#
# Frame 50: 25.00 seconds
# label found
#
#
# Frame 51: 25.50 seconds
# label found
#
#
# Frame 52: 26.00 seconds
# label found
#
#
# Frame 53: 26.50 seconds
# label found
#
#
# Frame 54: 27.00 seconds
# label found
#
#
# Frame 55: 27.50 seconds
# label found
#
#
# Frame 56: 28.00 seconds
# label found
#
#
# Frame 57: 28.50 seconds
# label found
#
#
# Frame 58: 29.00 seconds
# label found
#
#
# Frame 59: 29.50 seconds
# label found
#
#
# Frame 60: 30.00 seconds
# label found
#
#
# Frame 61: 30.50 seconds
# label found
#
#
# Frame 62: 31.00 seconds
# label found
#
#
# Frame 63: 31.50 seconds
# label found
#
#
# Frame 64: 32.00 seconds
# label found
#
#
# Frame 65: 32.50 seconds
# label found
#
#
# Frame 66: 33.00 seconds
# Frame 67: 33.50 seconds
# label found
#
#
# Frame 68: 34.00 seconds
# label found
#
#
# Frame 69: 34.50 seconds
# label found
#
#
# Frame 70: 35.00 seconds
# label found
#
#
# Frame 71: 35.50 seconds
# label found
#
#
# Frame 72: 36.00 seconds
# label found
#
#
# Frame 73: 36.50 seconds
# label found
#
#
# Frame 74: 37.00 seconds
# label found
#
#
# Frame 75: 37.50 seconds
# label found
#
#
# Frame 76: 38.00 seconds
# label found
#
#
# Frame 77: 38.50 seconds
# label found
#
#
# Frame 78: 39.00 seconds
# label found
#
#
# Frame 79: 39.50 seconds
# Frame 80: 40.00 seconds
# Frame 81: 40.50 seconds
# label found
#
#
# Frame 82: 41.00 seconds
# label found
#
#
# Frame 83: 41.50 seconds
# label found
#
#
# Frame 84: 42.00 seconds
# label found
#
#
# Frame 85: 42.50 seconds
# label found
#
#
# Frame 86: 43.00 seconds
# label found
#
#
# Frame 87: 43.50 seconds
# label found
#
#
# Frame 88: 44.00 seconds
# label found
#
#
# Frame 89: 44.50 seconds
# label found
#
#
# Frame 90: 45.00 seconds
# label found
#
#
# Frame 91: 45.50 seconds
# label found
#
#
# Frame 92: 46.00 seconds
# label found
#
#
# Frame 93: 46.50 seconds
# label found
#
#
# Frame 94: 47.00 seconds
# Frame 95: 47.50 seconds
# Frame 96: 48.00 seconds
# Frame 97: 48.50 seconds
# label found
#
#
# Frame 98: 49.00 seconds
# label found
#
#
# Frame 99: 49.50 seconds
# label found
#
#
# Frame 100: 50.00 seconds
# label found
#
#
# Frame 101: 50.50 seconds
# label found
#
#
# Frame 102: 51.00 seconds
# label found
#
#
# Frame 103: 51.50 seconds
# label found
#
#
# Frame 104: 52.00 seconds
# label found
#
#
# Frame 105: 52.50 seconds
# label found
#
#
# Frame 106: 53.00 seconds
# label found
#
#
# Frame 107: 53.50 seconds
# label found
#
#
# Frame 108: 54.00 seconds
# label found
#
#
# Frame 109: 54.50 seconds
# label found
#
#
# Frame 110: 55.00 seconds
# label found
#
#
# Frame 111: 55.50 seconds
# label found
#
#
# Frame 112: 56.00 seconds
# label found
#
#
# Frame 113: 56.50 seconds
# label found
#
#
# Frame 114: 57.00 seconds
# label found
#
#
# Frame 115: 57.50 seconds
# label found
#
#
# Frame 116: 58.00 seconds
# label found
#
#
# Frame 117: 58.50 seconds
# label found
#
#
# Frame 118: 59.00 seconds
# label found
#
#
# Frame 119: 59.50 seconds
# label found
#
#
# Frame 120: 60.00 seconds
# label found
#
#
# Frame 121: 60.50 seconds
# label found
#
#
# Frame 122: 61.00 seconds
# label found
#
#
# Frame 123: 61.50 seconds
# label found
#
#
# Frame 124: 62.00 seconds
# label found
#
#
# Frame 125: 62.50 seconds
# label found
#
#
# Frame 126: 63.00 seconds
# label found
#
#
# Frame 127: 63.50 seconds
# label found
#
#
# Frame 128: 64.00 seconds
# label found
#
#
# Frame 129: 64.50 seconds
# label found
#
#
# Frame 130: 65.00 seconds
# label found
#
#
# Frame 131: 65.50 seconds
# label found
#
#
# Frame 132: 66.00 seconds
# label found
#
#
# Frame 133: 66.50 seconds
# label found
#
#
# Frame 134: 67.00 seconds
# label found
#
#
# Frame 135: 67.50 seconds
# label found
#
#
# Frame 136: 68.00 seconds
# label found
#
#
# Frame 137: 68.50 seconds
# label found
#
#
# Frame 138: 69.00 seconds
# label found
#
#
# Frame 139: 69.50 seconds
# label found
#
#
# Frame 140: 70.00 seconds
# label found
#
#
# Frame 141: 70.50 seconds
# label found
#
#
# Frame 142: 71.00 seconds
# label found
#
#
# Frame 143: 71.50 seconds
# label found
#
#
# Frame 144: 72.00 seconds
# label found
#
#
# Frame 145: 72.50 seconds
# label found
#
#
# Frame 146: 73.00 seconds
# label found
#
#
# Frame 147: 73.50 seconds
# Frame 148: 74.00 seconds
# label found
#
#
# Frame 149: 74.50 seconds
# label found
#
#
# Frame 150: 75.00 seconds
# label found
#
#
# Frame 151: 75.50 seconds
# label found
#
#
# Frame 152: 76.00 seconds
# label found
#
#
# Frame 153: 76.50 seconds
# label found
#
#
# Frame 154: 77.00 seconds
# Frame 155: 77.50 seconds
# Frame 156: 78.00 seconds
# label found
#
#
# Frame 157: 78.50 seconds
# Frame 158: 79.00 seconds
# Frame 159: 79.50 seconds
# Frame 160: 80.00 seconds
# label found

# %%
frame_dict
# Out:
# {'Frame 0: 0.00 seconds': [{'action video game shooting xbox': 0.251544279116603}],
#  'Frame 1: 0.50 seconds': [{'action video game shooting xbox': 0.2567858361741459}],
#  'Frame 2: 1.00 seconds': [{'action video game shooting xbox': 0.264930826243032}],
#  'Frame 3: 1.50 seconds': [{'action video game shooting xbox': 0.26455160526266686}],
#  'Frame 4: 2.00 seconds': [{'action video game shooting xbox': 0.2620280756204121}],
#  'Frame 5: 2.50 seconds': [{'action video game shooting xbox': 0.25951293189309643}],
#  'Frame 6: 3.00 seconds': [{'action video game shooting xbox': 0.27337254129373756}],
#  'Frame 7: 3.50 seconds': [{'action video game shooting xbox': 0.27337921634868095}],
#  'Frame 8: 4.00 seconds': [{'action video game shooting xbox': 0.26934443561608745}],
#  'Frame 9: 4.50 seconds': [{'action video game shooting xbox': 0.28382190441216126}],
#  'Frame 10: 5.00 seconds': [{'action video game shooting xbox': 0.25426001338438914}],
#  'Frame 11: 5.50 seconds': [{'action video game shooting xbox': 0.2857121689011761}],
#  'Frame 12: 6.00 seconds': [{'action video game shooting xbox': 0.26747703146933866}],
#  'Frame 13: 6.50 seconds': [{'action video game shooting xbox': 0.2838515535424833}],
#  'Frame 14: 7.00 seconds': [{'action video game shooting xbox': 0.2762068048795422}],
#  'Frame 15: 7.50 seconds': [{'action video game shooting xbox': 0.25074502616647054}],
#  'Frame 16: 8.00 seconds': [{'action video game shooting xbox': 0.2620093002233728}],
#  'Frame 17: 8.50 seconds': [{'action video game shooting xbox': 0.26724079565059566}],
#  'Frame 18: 9.00 seconds': [{'action video game shooting xbox': 0.27255353975570706}],
#  'Frame 19: 9.50 seconds': [{'action video game shooting xbox': 0.27246428751223856}],
#  'Frame 20: 10.00 seconds': [{'action video game shooting xbox': 0.25604766934675005}],
#  'Frame 21: 10.50 seconds': [{'Drake rapper music': 0.2852440045098531}],
#  'Frame 22: 11.00 seconds': [{'Drake rapper music': 0.2986185267688645}],
#  'Frame 23: 11.50 seconds': [{'Drake rapper music': 0.30189190534092464}],
#  'Frame 24: 12.00 seconds': [{'Drake rapper music': 0.2832604035400707}],
#  'Frame 25: 12.50 seconds': [{'Drake rapper music': 0.29112512830049314}],
#  'Frame 26: 13.00 seconds': [{'Drake rapper music': 0.28955762280866304}],
#  'Frame 27: 13.50 seconds': [{'beyonce': 0.2579466384707376}],
#  'Frame 28: 14.00 seconds': [{'beyonce': 0.2643446863041142}],
#  'Frame 29: 14.50 seconds': [{'Drake rapper music': 0.2693124698614827}],
#  'Frame 30: 15.00 seconds': [{'Drake rapper music': 0.3045701130595081}],
#  'Frame 31: 15.50 seconds': [{'Drake rapper music': 0.30078897464226373}],
#  'Frame 32: 16.00 seconds': [{'Drake rapper music': 0.2896128508728653}],
#  'Frame 33: 16.50 seconds': [{'Drake rapper music': 0.29701714781282174}],
#  'Frame 34: 17.00 seconds': [{'beyonce': 0.2670896185609763}],
#  'Frame 35: 17.50 seconds': [{'beyonce': 0.26675275812103916}],
#  'Frame 36: 18.00 seconds': [{'Drake rapper music': 0.3014483446408932}],
#  'Frame 37: 18.50 seconds': [{'Drake rapper music': 0.28886610456942907}],
#  'Frame 38: 19.00 seconds': [{'Drake rapper music': 0.29264808695741784}],
#  'Frame 39: 19.50 seconds': [{'Drake rapper music': 0.28984402165117185}],
#  'Frame 40: 20.00 seconds': [{'Drake rapper music': 0.2880038237783347}],
#  'Frame 41: 20.50 seconds': [{'soccer game ball': 0.23139801479438776}],
#  'Frame 42: 21.00 seconds': [{'soccer game ball': 0.22252893175756017}],
#  'Frame 43: 21.50 seconds': [{'soccer game ball': 0.22540529318628874}],
#  'Frame 44: 22.00 seconds': [{'soccer game ball': 0.21880062180236967}],
#  'Frame 45: 22.50 seconds': [{'soccer game ball': 0.22748824119920052}],
#  'Frame 46: 23.00 seconds': [{'soccer game ball': 0.23835699155758175}],
#  'Frame 47: 23.50 seconds': [{'soccer game ball': 0.25680370433538485}],
#  'Frame 48: 24.00 seconds': [{'soccer game ball': 0.25647643076271726}],
#  'Frame 49: 24.50 seconds': [{'soccer game ball': 0.2673557392576088}],
#  'Frame 50: 25.00 seconds': [{'soccer game ball': 0.25896280782669073}],
#  'Frame 51: 25.50 seconds': [{'soccer game ball': 0.26132472123302275}],
#  'Frame 52: 26.00 seconds': [{'soccer game ball': 0.24804915779573758}],
#  'Frame 53: 26.50 seconds': [{'soccer game ball': 0.2609093086226304}],
#  'Frame 54: 27.00 seconds': [{'soccer game ball': 0.24353848932985442}],
#  'Frame 55: 27.50 seconds': [{'soccer game ball': 0.2541450994603446}],
#  'Frame 56: 28.00 seconds': [{'soccer game ball': 0.24628378052770528}],
#  'Frame 57: 28.50 seconds': [{'soccer game ball': 0.26825849151062675}],
#  'Frame 58: 29.00 seconds': [{'soccer game ball': 0.24490524633801058}],
#  'Frame 59: 29.50 seconds': [{'soccer game ball': 0.23580016981968732}],
#  'Frame 60: 30.00 seconds': [{'soccer game ball': 0.24169699480021284}],
#  'Frame 61: 30.50 seconds': [{'Drake rapper music': 0.23220301318826495}],
#  'Frame 62: 31.00 seconds': [{'beyonce': 0.22855872201456495}],
#  'Frame 63: 31.50 seconds': [{'action video game shooting xbox': 0.22966651345276343}],
#  'Frame 64: 32.00 seconds': [{'Drake rapper music': 0.24319831391056543}],
#  'Frame 65: 32.50 seconds': [{'Drake rapper music': 0.23718754598373312}],
#  'Frame 66: 33.00 seconds': [],
#  'Frame 67: 33.50 seconds': [{'action video game shooting xbox': 0.22552064475303096}],
#  'Frame 68: 34.00 seconds': [{'marvel combic book': 0.22686162462097992}],
#  'Frame 69: 34.50 seconds': [{'action video game shooting xbox': 0.2369623871134385}],
#  'Frame 70: 35.00 seconds': [{'marvel combic book': 0.27576376538081354}],
#  'Frame 71: 35.50 seconds': [{'marvel combic book': 0.27686366021037834}],
#  'Frame 72: 36.00 seconds': [{'marvel combic book': 0.27708969131343053}],
#  'Frame 73: 36.50 seconds': [{'marvel combic book': 0.2679790695689363}],
#  'Frame 74: 37.00 seconds': [{'marvel combic book': 0.26406056945114065}],
#  'Frame 75: 37.50 seconds': [{'action video game shooting xbox': 0.2179164094150582}],
#  'Frame 76: 38.00 seconds': [{'action video game shooting xbox': 0.21886625137390311}],
#  'Frame 77: 38.50 seconds': [{'action video game shooting xbox': 0.22235461131345488}],
#  'Frame 78: 39.00 seconds': [{'action video game shooting xbox': 0.22100314772684748}],
#  'Frame 79: 39.50 seconds': [],
#  'Frame 80: 40.00 seconds': [],
#  'Frame 81: 40.50 seconds': [{'beyonce': 0.2666886714012859}],
#  'Frame 82: 41.00 seconds': [{'beyonce': 0.25500706978711213}],
#  'Frame 83: 41.50 seconds': [{'beyonce': 0.2446501677594552}],
#  'Frame 84: 42.00 seconds': [{'beyonce': 0.2817706656537277}],
#  'Frame 85: 42.50 seconds': [{'beyonce': 0.2688018683820392}],
#  'Frame 86: 43.00 seconds': [{'beyonce': 0.24327666380461643}],
#  'Frame 87: 43.50 seconds': [{'beyonce': 0.2810027396476703}],
#  'Frame 88: 44.00 seconds': [{'beyonce': 0.28734866167444534}],
#  'Frame 89: 44.50 seconds': [{'beyonce': 0.28444089029469266}],
#  'Frame 90: 45.00 seconds': [{'beyonce': 0.28995148701673473}],
#  'Frame 91: 45.50 seconds': [{'beyonce': 0.2274491661988895}],
#  'Frame 92: 46.00 seconds': [{'beyonce': 0.22952758161037579}],
#  'Frame 93: 46.50 seconds': [{'beyonce': 0.22036856733714372}],
#  'Frame 94: 47.00 seconds': [],
#  'Frame 95: 47.50 seconds': [],
#  'Frame 96: 48.00 seconds': [],
#  'Frame 97: 48.50 seconds': [{'beyonce': 0.2649672499814629}],
#  'Frame 98: 49.00 seconds': [{'beyonce': 0.2869560164061092}],
#  'Frame 99: 49.50 seconds': [{'beyonce': 0.2561631018416872}],
#  'Frame 100: 50.00 seconds': [{'beyonce': 0.28299751261423817}],
#  'Frame 101: 50.50 seconds': [{'Mcdonalds French Fries': 0.2807689470649367}],
#  'Frame 102: 51.00 seconds': [{'Mcdonalds French Fries': 0.28314926861358575}],
#  'Frame 103: 51.50 seconds': [{'Mcdonalds French Fries': 0.28577609560131456}],
#  'Frame 104: 52.00 seconds': [{'Mcdonalds French Fries': 0.2847520566792701}],
#  'Frame 105: 52.50 seconds': [{'Mcdonalds French Fries': 0.2953702394369351}],
#  'Frame 106: 53.00 seconds': [{'Mcdonalds French Fries': 0.288302481989841}],
#  'Frame 107: 53.50 seconds': [{'Mcdonalds French Fries': 0.3034614579352161}],
#  'Frame 108: 54.00 seconds': [{'Mcdonalds French Fries': 0.30295245145534494}],
#  'Frame 109: 54.50 seconds': [{'Mcdonalds French Fries': 0.31119307167988286}],
#  'Frame 110: 55.00 seconds': [{'Mcdonalds French Fries': 0.27280380402740817}],
#  'Frame 111: 55.50 seconds': [{'Mcdonalds French Fries': 0.272295260292384}],
#  'Frame 112: 56.00 seconds': [{'Mcdonalds French Fries': 0.2804122391535596}],
#  'Frame 113: 56.50 seconds': [{'Mcdonalds French Fries': 0.285305192648669}],
#  'Frame 114: 57.00 seconds': [{'Mcdonalds French Fries': 0.27935591501638657}],
#  'Frame 115: 57.50 seconds': [{'action video game shooting xbox': 0.22575610327434292}],
#  'Frame 116: 58.00 seconds': [{'action video game shooting xbox': 0.2432969359803162}],
#  'Frame 117: 58.50 seconds': [{'Mcdonalds French Fries': 0.26513409516836195}],
#  'Frame 118: 59.00 seconds': [{'Mcdonalds French Fries': 0.26927225165262614}],
#  'Frame 119: 59.50 seconds': [{'Mcdonalds French Fries': 0.26172654881451457}],
#  'Frame 120: 60.00 seconds': [{'Mcdonalds French Fries': 0.25697256948931063}],
#  'Frame 121: 60.50 seconds': [{'Church pope praying': 0.24956456765825055}],
#  'Frame 122: 61.00 seconds': [{'beyonce': 0.23701585941793554}],
#  'Frame 123: 61.50 seconds': [{'Church pope praying': 0.23831072563019898}],
#  'Frame 124: 62.00 seconds': [{'Church pope praying': 0.24332643713933808}],
#  'Frame 125: 62.50 seconds': [{'Church pope praying': 0.23635076635830196}],
#  'Frame 126: 63.00 seconds': [{'Church pope praying': 0.24710084332781534}],
#  'Frame 127: 63.50 seconds': [{'Church pope praying': 0.24810855175467636}],
#  'Frame 128: 64.00 seconds': [{'Church pope praying': 0.23064371796044794}],
#  'Frame 129: 64.50 seconds': [{'Church pope praying': 0.24201128686579904}],
#  'Frame 130: 65.00 seconds': [{'Church pope praying': 0.2337803760562041}],
#  'Frame 131: 65.50 seconds': [{'Church pope praying': 0.23497960919624344}],
#  'Frame 132: 66.00 seconds': [{'Church pope praying': 0.2363776835488568}],
#  'Frame 133: 66.50 seconds': [{'Church pope praying': 0.24901721542965072}],
#  'Frame 134: 67.00 seconds': [{'Church pope praying': 0.2477774278783499}],
#  'Frame 135: 67.50 seconds': [{'Church pope praying': 0.24966429253933453}],
#  'Frame 136: 68.00 seconds': [{'Church pope praying': 0.25107256914011}],
#  'Frame 137: 68.50 seconds': [{'Church pope praying': 0.25369789417154304}],
#  'Frame 138: 69.00 seconds': [{'Church pope praying': 0.24956319932608734}],
#  'Frame 139: 69.50 seconds': [{'Church pope praying': 0.2532681323017523}],
#  'Frame 140: 70.00 seconds': [{'Church pope praying': 0.24941134919154853}],
#  'Frame 141: 70.50 seconds': [{'action video game shooting xbox': 0.19625243252216587}],
#  'Frame 142: 71.00 seconds': [{'soccer game ball': 0.23918629221730014}],
#  'Frame 143: 71.50 seconds': [{'action video game shooting xbox': 0.24144659734288937}],
#  'Frame 144: 72.00 seconds': [{'action video game shooting xbox': 0.26195295659538304}],
#  'Frame 145: 72.50 seconds': [{'action video game shooting xbox': 0.2360244388810184}],
#  'Frame 146: 73.00 seconds': [{'action video game shooting xbox': 0.2403293956589546}],
#  'Frame 147: 73.50 seconds': [],
#  'Frame 148: 74.00 seconds': [{'action video game shooting xbox': 0.2294456795246239}],
#  'Frame 149: 74.50 seconds': [{'action video game shooting xbox': 0.23934690852944726}],
#  'Frame 150: 75.00 seconds': [{'action video game shooting xbox': 0.23611256000483047}],
#  'Frame 151: 75.50 seconds': [{'action video game shooting xbox': 0.22049768454337623}],
#  'Frame 152: 76.00 seconds': [{'Drake rapper music': 0.23532861569453525}],
#  'Frame 153: 76.50 seconds': [{'action video game shooting xbox': 0.22859412713794164}],
#  'Frame 154: 77.00 seconds': [],
#  'Frame 155: 77.50 seconds': [],
#  'Frame 156: 78.00 seconds': [{'action video game shooting xbox': 0.23236725248039103}],
#  'Frame 157: 78.50 seconds': [],
#  'Frame 158: 79.00 seconds': [],
#  'Frame 159: 79.50 seconds': [],
#  'Frame 160: 80.00 seconds': [{'action video game shooting xbox': 0.2419222395686734}]}

# %%
# Flatten the nested dictionary
data = frame_dict
# Define the threshold
threshold = 0.22

# Filter out key-value pairs below the threshold for each frame
filtered_data = [
    {
        frame: [
            {key: value}
            for item in items
            for key, value in item.items()
            if value > threshold
        ]
    }
    for frame, items in data.items()
]

print(filtered_data)
# Out:
# [{'Frame 0: 0.00 seconds': [{'action video game shooting xbox': 0.251544279116603}]}, {'Frame 1: 0.50 seconds': [{'action video game shooting xbox': 0.2567858361741459}]}, {'Frame 2: 1.00 seconds': [{'action video game shooting xbox': 0.264930826243032}]}, {'Frame 3: 1.50 seconds': [{'action video game shooting xbox': 0.26455160526266686}]}, {'Frame 4: 2.00 seconds': [{'action video game shooting xbox': 0.2620280756204121}]}, {'Frame 5: 2.50 seconds': [{'action video game shooting xbox': 0.25951293189309643}]}, {'Frame 6: 3.00 seconds': [{'action video game shooting xbox': 0.27337254129373756}]}, {'Frame 7: 3.50 seconds': [{'action video game shooting xbox': 0.27337921634868095}]}, {'Frame 8: 4.00 seconds': [{'action video game shooting xbox': 0.26934443561608745}]}, {'Frame 9: 4.50 seconds': [{'action video game shooting xbox': 0.28382190441216126}]}, {'Frame 10: 5.00 seconds': [{'action video game shooting xbox': 0.25426001338438914}]}, {'Frame 11: 5.50 seconds': [{'action video game shooting xbox': 0.2857121689011761}]}, {'Frame 12: 6.00 seconds': [{'action video game shooting xbox': 0.26747703146933866}]}, {'Frame 13: 6.50 seconds': [{'action video game shooting xbox': 0.2838515535424833}]}, {'Frame 14: 7.00 seconds': [{'action video game shooting xbox': 0.2762068048795422}]}, {'Frame 15: 7.50 seconds': [{'action video game shooting xbox': 0.25074502616647054}]}, {'Frame 16: 8.00 seconds': [{'action video game shooting xbox': 0.2620093002233728}]}, {'Frame 17: 8.50 seconds': [{'action video game shooting xbox': 0.26724079565059566}]}, {'Frame 18: 9.00 seconds': [{'action video game shooting xbox': 0.27255353975570706}]}, {'Frame 19: 9.50 seconds': [{'action video game shooting xbox': 0.27246428751223856}]}, {'Frame 20: 10.00 seconds': [{'action video game shooting xbox': 0.25604766934675005}]}, {'Frame 21: 10.50 seconds': [{'Drake rapper music': 0.2852440045098531}]}, {'Frame 22: 11.00 seconds': [{'Drake rapper music': 0.2986185267688645}]}, {'Frame 23: 11.50 seconds': [{'Drake rapper music': 0.30189190534092464}]}, {'Frame 24: 12.00 seconds': [{'Drake rapper music': 0.2832604035400707}]}, {'Frame 25: 12.50 seconds': [{'Drake rapper music': 0.29112512830049314}]}, {'Frame 26: 13.00 seconds': [{'Drake rapper music': 0.28955762280866304}]}, {'Frame 27: 13.50 seconds': [{'beyonce': 0.2579466384707376}]}, {'Frame 28: 14.00 seconds': [{'beyonce': 0.2643446863041142}]}, {'Frame 29: 14.50 seconds': [{'Drake rapper music': 0.2693124698614827}]}, {'Frame 30: 15.00 seconds': [{'Drake rapper music': 0.3045701130595081}]}, {'Frame 31: 15.50 seconds': [{'Drake rapper music': 0.30078897464226373}]}, {'Frame 32: 16.00 seconds': [{'Drake rapper music': 0.2896128508728653}]}, {'Frame 33: 16.50 seconds': [{'Drake rapper music': 0.29701714781282174}]}, {'Frame 34: 17.00 seconds': [{'beyonce': 0.2670896185609763}]}, {'Frame 35: 17.50 seconds': [{'beyonce': 0.26675275812103916}]}, {'Frame 36: 18.00 seconds': [{'Drake rapper music': 0.3014483446408932}]}, {'Frame 37: 18.50 seconds': [{'Drake rapper music': 0.28886610456942907}]}, {'Frame 38: 19.00 seconds': [{'Drake rapper music': 0.29264808695741784}]}, {'Frame 39: 19.50 seconds': [{'Drake rapper music': 0.28984402165117185}]}, {'Frame 40: 20.00 seconds': [{'Drake rapper music': 0.2880038237783347}]}, {'Frame 41: 20.50 seconds': [{'soccer game ball': 0.23139801479438776}]}, {'Frame 42: 21.00 seconds': [{'soccer game ball': 0.22252893175756017}]}, {'Frame 43: 21.50 seconds': [{'soccer game ball': 0.22540529318628874}]}, {'Frame 44: 22.00 seconds': []}, {'Frame 45: 22.50 seconds': [{'soccer game ball': 0.22748824119920052}]}, {'Frame 46: 23.00 seconds': [{'soccer game ball': 0.23835699155758175}]}, {'Frame 47: 23.50 seconds': [{'soccer game ball': 0.25680370433538485}]}, {'Frame 48: 24.00 seconds': [{'soccer game ball': 0.25647643076271726}]}, {'Frame 49: 24.50 seconds': [{'soccer game ball': 0.2673557392576088}]}, {'Frame 50: 25.00 seconds': [{'soccer game ball': 0.25896280782669073}]}, {'Frame ...

# %%
# Specify the filename for the JSON file
import json
filename = 'telly_clip'+str(threshold)+'.json'

# Write the dictionary to the JSON file
with open(filename, 'w') as json_file:
    json.dump(filtered_data, json_file, indent=4)  # The indent parameter is optional for pretty-printing

#print(f'Data has been written to {filename})

# %% [markdown]
# ## extra

# %%
#print(os.path.exists(VIDEO))
import time
max_retries = 4

total_frames = 171
total_seconds = 80
stride_length = 30
frames_per_second = total_frames / total_seconds
frame_dict = {}
num_frames = 0
for frame_index,frame in enumerate(sv.get_video_frames_generator(source_path=VIDEO,stride=stride_length,start =0)):
    frame_second = frame_index * (1 / frames_per_second)
    frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"] = []
    if frame_index < 3:
        print(f"Frame {frame_index}: {frame_second:.2f} seconds")
        for prompt in prompt_list:
            try: 
                label,similarity = classify_image(frame)
                if label == prompt[0]:
                    print('label found')
                    frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"].append({label:similarity})
                    #frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"].append(similarity)
                    
                    print('\n')
            except Exception as e:
                print(f"Error: {e}")
                print(f"Retrying... (Attempt {retries + 1}/{max_retries})")
                retries += 1
                time.sleep(1)  # Wait for a short period before retrying
# Out:
# Frame 0: 0.00 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 1: 0.47 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 2: 0.94 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 3: 1.40 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 4: 1.87 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 5: 2.34 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 6: 2.81 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 7: 3.27 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 8: 3.74 seconds
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# label found
#
#
# Frame 9: 4.21 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 18
#      16 for prompt in prompt_list:
#      17     try:
# ---> 18         label,similarity = classify_image(frame)
#      19         if label == prompt[0]:
#      20             print('label found')
#
# Cell In[3], line 18, in classify_image(image)
#       7 image_data = base64.b64encode(buffer.getvalue()).decode("utf-8")
#       9 payload = {
#      10     "api_key": API_KEY,
#      11     "subject": {
#    (...)
#      15     "prompt": prompt,
#      16 }
# ---> 18 data = requests.post(INFERENCE_ENDPOINT + "/clip/compare?api_key=" + API_KEY, json=payload)
#      20 response = data.json()
#      21 #print(response["similarity"])
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/urllib3/connection.py:454, in HTTPConnection.getresponse(self)
#     451 from .response import HTTPResponse
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#     457     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/magic/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/anaconda3/envs/magic/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/anaconda3/envs/magic/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/magic/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/anaconda3/envs/magic/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/magic/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
frame_dict
# Out:
# {'Frame 0: 0.00 seconds': [{'action video game shooting xbox': 0.251544279116603}],
#  'Frame 1: 0.50 seconds': [{'action video game shooting xbox': 0.2567858361741459}],
#  'Frame 2: 1.00 seconds': [{'action video game shooting xbox': 0.264930826243032},
#   {'youtube video commercial trailer': 0.22509281064762096}],
#  'Frame 3: 1.49 seconds': [{'action video game shooting xbox': 0.26455160526266686},
#   {'youtube video commercial trailer': 0.22196117136207832}],
#  'Frame 4: 1.99 seconds': [{'action video game shooting xbox': 0.2620280756204121},
#   {'youtube video commercial trailer': 0.2330172919859395}],
#  'Frame 5: 2.49 seconds': [{'action video game shooting xbox': 0.25951293189309643},
#   {'youtube video commercial trailer': 0.22166856130776694}],
#  'Frame 6: 2.99 seconds': [{'action video game shooting xbox': 0.27337254129373756}],
#  'Frame 7: 3.48 seconds': [{'action video game shooting xbox': 0.27337921634868095},
#   {'youtube video commercial trailer': 0.23314553655320758}],
#  'Frame 8: 3.98 seconds': [{'action video game shooting xbox': 0.26934443561608745},
#   {'youtube video commercial trailer': 0.22343057019229995}],
#  'Frame 9: 4.48 seconds': [{'action video game shooting xbox': 0.28382190441216126}],
#  'Frame 10: 4.98 seconds': [{'action video game shooting xbox': 0.25426001338438914}],
#  'Frame 11: 5.48 seconds': [{'action video game shooting xbox': 0.2857121689011761},
#   {'church holy cross': 0.18764132215722978}],
#  'Frame 12: 5.97 seconds': [{'action video game shooting xbox': 0.26747703146933866},
#   {'church holy cross': 0.19070611380004288}],
#  'Frame 13: 6.47 seconds': [{'action video game shooting xbox': 0.2838515535424833}],
#  'Frame 14: 6.97 seconds': [{'action video game shooting xbox': 0.2762068048795422}],
#  'Frame 15: 7.47 seconds': [{'action video game shooting xbox': 0.25074502616647054}],
#  'Frame 16: 7.96 seconds': [{'action video game shooting xbox': 0.2620093002233728}],
#  'Frame 17: 8.46 seconds': [{'action video game shooting xbox': 0.26724079565059566},
#   {'youtube video commercial trailer': 0.23878733046377246}],
#  'Frame 18: 8.96 seconds': [{'action video game shooting xbox': 0.27255353975570706}],
#  'Frame 19: 9.46 seconds': [{'action video game shooting xbox': 0.27246428751223856}],
#  'Frame 20: 9.95 seconds': [{'action video game shooting xbox': 0.25604766934675005},
#   {'youtube video commercial trailer': 0.26330615507847444}],
#  'Frame 21: 10.45 seconds': [{'Drake rapper music': 0.2852440045098531},
#   {'youtube video commercial trailer': 0.24491280174877503}],
#  'Frame 22: 10.95 seconds': [{'Drake rapper music': 0.2986185267688645}],
#  'Frame 23: 11.45 seconds': [{'Drake rapper music': 0.30189190534092464}],
#  'Frame 24: 11.95 seconds': [{'Drake rapper music': 0.2832604035400707}],
#  'Frame 25: 12.44 seconds': [{'Drake rapper music': 0.29112512830049314}],
#  'Frame 26: 12.94 seconds': [{'Drake rapper music': 0.28955762280866304}],
#  'Frame 27: 13.44 seconds': [{'action video game shooting xbox': 0.22912972480307303},
#   {'Drake rapper music': 0.24120738680853687},
#   {'beyonce': 0.2579466384707376},
#   {'youtube video commercial trailer': 0.23668222000131672}],
#  'Frame 28: 13.94 seconds': [{'action video game shooting xbox': 0.22804551514077118},
#   {'Drake rapper music': 0.24224059504396306},
#   {'beyonce': 0.2643446863041142},
#   {'youtube video commercial trailer': 0.2348973417412327}],
#  'Frame 29: 14.43 seconds': [{'Drake rapper music': 0.2693124698614827},
#   {'beyonce': 0.24075265096325807},
#   {'youtube video commercial trailer': 0.2580352231203364}],
#  'Frame 30: 14.93 seconds': [{'Drake rapper music': 0.3045701130595081}],
#  'Frame 31: 15.43 seconds': [{'Drake rapper music': 0.30078897464226373}],
#  'Frame 32: 15.93 seconds': [{'Drake rapper music': 0.2896128508728653}],
#  'Frame 33: 16.43 seconds': [{'Drake rapper music': 0.29701714781282174}],
#  'Frame 34: 16.92 seconds': [{'Drake rapper music': 0.24737239038240566},
#   {'beyonce': 0.2670896185609763},
#   {'French Fries Mcdonalds': 0.1992047322321328}],
#  'Frame 35: 17.42 seconds': [{'Drake rapper music': 0.24732022040332496},
#   {'beyonce': 0.26675275812103916},
#   {'French Fries Mcdonalds': 0.1981022228296821}],
#  'Frame 36: 17.92 seconds': [{'Drake rapper music': 0.3014483446408932}],
#  'Frame 37: 18.42 seconds': [{'Drake rapper music': 0.28886610456942907}],
#  'Frame 38: 18.91 seconds': [{'Drake rapper music': 0.29264808695741784}],
#  'Frame 39: 19.41 seconds': [{'Drake rapper music': 0.28984402165117185}],
#  'Frame 40: 19.91 seconds': [{'Drake rapper music': 0.2888288281006909}],
#  'Frame 41: 20.41 seconds': [{'flower picnic grass people': 0.2227313324743228},
#   {'beyonce': 0.21343921880279912},
#   {'youtube video commercial trailer': 0.22825487717459472}],
#  'Frame 42: 20.90 seconds': [{'beyonce': 0.21024673390585596}],
#  'Frame 43: 21.40 seconds': [{'beyonce': 0.22649241830290776},
#   {'youtube video commercial trailer': 0.24237036183327712}],
#  'Frame 44: 21.90 seconds': [{'beyonce': 0.22237544120380398}],
#  'Frame 45: 22.40 seconds': [{'beyonce': 0.21051484596048906},
#   {'youtube video commercial trailer': 0.23964067415988494}],
#  'Frame 46: 22.90 seconds': [{'beyonce': 0.20923233963258803},
#   {'youtube video commercial trailer': 0.23414968882713963}],
#  'Frame 47: 23.39 seconds': [{'flower picnic grass people': 0.1807017415794914},
#   {'beyonce': 0.19758196810527892},
#   {'youtube video commercial trailer': 0.25054179227694556}],
#  'Frame 48: 23.89 seconds': [{'beyonce': 0.2262759846974932}],
#  'Frame 49: 24.39 seconds': [{'flower picnic grass people': 0.20654361871812085},
#   {'beyonce': 0.22192697454493354}],
#  'Frame 50: 24.89 seconds': [{'flower picnic grass people': 0.17845121286864868},
#   {'beyonce': 0.21251781716801232}],
#  'Frame 51: 25.38 seconds': [{'beyonce': 0.2392052976536575}],
#  'Frame 52: 25.88 seconds': [],
#  'Frame 53: 26.38 seconds': [{'flower picnic grass people': 0.1991438050900088},
#   {'beyonce': 0.247035829547941},
#   {'French Fries Mcdonalds': 0.17330113734927413},
#   {'youtube video commercial trailer': 0.23560361645566724}],
#  'Frame 54: 26.88 seconds': [{'flower picnic grass people': 0.22192884198046675},
#   {'beyonce': 0.2401063863374575}],
#  'Frame 55: 27.38 seconds': [{'flower picnic grass people': 0.2116623059114014},
#   {'beyonce': 0.253498982123793},
#   {'French Fries Mcdonalds': 0.18103874501517428}],
#  'Frame 56: 27.87 seconds': [{'flower picnic grass people': 0.20699210918425778},
#   {'beyonce': 0.2338494564752178}],
#  'Frame 57: 28.37 seconds': [{'flower picnic grass people': 0.19899848391482775},
#   {'beyonce': 0.20432291474578693}],
#  'Frame 58: 28.87 seconds': [{'flower picnic grass people': 0.19229677720800448},
#   {'beyonce': 0.20177359122149985}],
#  'Frame 59: 29.37 seconds': [{'flower picnic grass people': 0.21596435403807032},
#   {'soccer game soccer ball grass': 0.1685849914523285},
#   {'beyonce': 0.1974610250555313}],
#  'Frame 60: 29.86 seconds': [{'flower picnic grass people': 0.20426164570826516},
#   {'beyonce': 0.1921656393141456}],
#  'Frame 61: 30.36 seconds': [{'soccer game soccer ball grass': 0.22207445707491852}],
#  'Frame 62: 30.86 seconds': [{'action video game shooting xbox': 0.19311056685473124},
#   {'soccer game soccer ball grass': 0.22135971387386885},
#   {'beyonce': 0.1800039371751385}],
#  'Frame 63: 31.36 seconds': [{'action video game shooting xbox': 0.19434780233504365},
#   {'soccer game soccer ball grass': 0.22603656151491},
#   {'beyonce': 0.18764854910994855}],
#  'Frame 64: 31.86 seconds': [{'soccer game soccer ball grass': 0.20922929287891265},
#   {'beyonce': 0.18436369786731815}],
#  'Frame 65: 32.35 seconds': [{'action video game shooting xbox': 0.1937477659583338},
#   {'soccer game soccer ball grass': 0.2169894549786027},
#   {'beyonce': 0.18158096635239757}],
#  'Frame 66: 32.85 seconds': [{'action video game shooting xbox': 0.20448531550247118},
#   {'soccer game soccer ball grass': 0.23253043563234804},
#   {'beyonce': 0.18772455665528676}],
#  'Frame 67: 33.35 seconds': [{'soccer game soccer ball grass': 0.24080037818954605}],
#  'Frame 68: 33.85 seconds': [{'soccer game soccer ball grass': 0.24747755084794718}],
#  'Frame 69: 34.34 seconds': [{'action video game shooting xbox': 0.22319781236216693},
#   {'soccer game soccer ball grass': 0.25485525892995853}],
#  'Frame 70: 34.84 seconds': [{'soccer game soccer ball grass': 0.257950381250167}],
#  'Frame 71: 35.34 seconds': [{'soccer game soccer ball grass': 0.2556144263839783}],
#  'Frame 72: 35.84 seconds': [{'action video game shooting xbox': 0.20177379751926952},
#   {'soccer game soccer ball grass': 0.2359556531160529}],
#  'Frame 73: 36.33 seconds': [{'action video game shooting xbox': 0.22381823307655552},
#   {'soccer game soccer ball grass': 0.2442216206454068}],
#  'Frame 74: 36.83 seconds': [{'action video game shooting xbox': 0.2021603890329001},
#   {'soccer game soccer ball grass': 0.22711621178432792}],
#  'Frame 75: 37.33 seconds': [{'soccer game soccer ball grass': 0.23427457549358255}],
#  'Frame 76: 37.83 seconds': [{'soccer game soccer ball grass': 0.23095316988536263}],
#  'Frame 77: 38.33 seconds': [{'action video game shooting xbox': 0.2145071460275986},
#   {'soccer game soccer ball grass': 0.24109842299692333}],
#  'Frame 78: 38.82 seconds': [{'action video game shooting xbox': 0.2126772265791854},
#   {'soccer game soccer ball grass': 0.23617566088285322}],
#  'Frame 79: 39.32 seconds': [{'action video game shooting xbox': 0.20128953773136285},
#   {'soccer game soccer ball grass': 0.20810904186228815},
#   {'beyonce': 0.17500430799025413}],
#  'Frame 80: 39.82 seconds': [{'action video game shooting xbox': 0.23461323133013118},
#   {'soccer game soccer ball grass': 0.23954071439066146}],
#  'Frame 81: 40.32 seconds': [{'youtube video commercial trailer': 0.2246333395066307}],
#  'Frame 82: 40.81 seconds': [{'Drake rapper music': 0.23086800985474945},
#   {'beyonce': 0.232224747341206},
#   {'youtube video commercial trailer': 0.250981752454855}],
#  'Frame 83: 41.31 seconds': [{'beyonce': 0.22941408590733856},
#   {'youtube video commercial trailer': 0.25355543953680415}],
#  'Frame 84: 41.81 seconds': [{'Drake rapper music': 0.24430252499149446},
#   {'beyonce': 0.22876201661217077},
#   {'youtube video commercial trailer': 0.263926690839297}],
#  'Frame 85: 42.31 seconds': [{'youtube video commercial trailer': 0.27076874656957434}],
#  'Frame 86: 42.81 seconds': [{'youtube video commercial trailer': 0.2639274551947569}],
#  'Frame 87: 43.30 seconds': [{'youtube video commercial trailer': 0.24817189606129303}],
#  'Frame 88: 43.80 seconds': [{'youtube video commercial trailer': 0.23671127122805644}],
#  'Frame 89: 44.30 seconds': [{'youtube video commercial trailer': 0.24011477407688664}],
#  'Frame 90: 44.80 seconds': [{'marvel combic book hero': 0.27167380827048604},
#   {'youtube video commercial trailer': 0.26304376572613614}],
#  'Frame 91: 45.29 seconds': [{'marvel combic book hero': 0.2730136111054656},
#   {'beyonce': 0.1893720112375315},
#   {'youtube video commercial trailer': 0.2421641692114868}],
#  'Frame 92: 45.79 seconds': [{'marvel combic book hero': 0.27024682048499593},
#   {'youtube video commercial trailer': 0.24763723230129298}],
#  'Frame 93: 46.29 seconds': [{'marvel combic book hero': 0.26334631098464734},
#   {'youtube video commercial trailer': 0.24683225730742428}],
#  'Frame 94: 46.79 seconds': [{'marvel combic book hero': 0.25811425813882466},
#   {'beyonce': 0.1756787976347363},
#   {'youtube video commercial trailer': 0.24064114707531328}],
#  'Frame 95: 47.29 seconds': [{'action video game shooting xbox': 0.21804072501261054},
#   {'Drake rapper music': 0.20883436004004519},
#   {'beyonce': 0.20096796855500182},
#   {'youtube video commercial trailer': 0.23025671716097537}],
#  'Frame 96: 47.78 seconds': [{'action video game shooting xbox': 0.2161529836928574},
#   {'Drake rapper music': 0.20932612731155345},
#   {'beyonce': 0.20326262254931887},
#   {'youtube video commercial trailer': 0.23053818182378913}],
#  'Frame 97: 48.28 seconds': [{'action video game shooting xbox': 0.21630790299690594},
#   {'Drake rapper music': 0.21437936318307482},
#   {'beyonce': 0.21133088058690916},
#   {'youtube video commercial trailer': 0.23588021903884918}],
#  'Frame 98: 48.78 seconds': [{'action video game shooting xbox': 0.2214312050830235},
#   {'Drake rapper music': 0.21570797330445024},
#   {'beyonce': 0.21866562319056868},
#   {'youtube video commercial trailer': 0.23938023541248257}],
#  'Frame 99: 49.28 seconds': [{'youtube video commercial trailer': 0.25741287162601934}],
#  'Frame 100: 49.77 seconds': [{'youtube video commercial trailer': 0.26055291979437434}],
#  'Frame 101: 50.27 seconds': [{'Drake rapper music': 0.20146648352836014},
#   {'beyonce': 0.2663262775418107},
#   {'French Fries Mcdonalds': 0.19553087714303993},
#   {'youtube video commercial trailer': 0.2240205224665431}],
#  'Frame 102: 50.77 seconds': [{'Drake rapper music': 0.2148393552046327},
#   {'beyonce': 0.2575615958083052},
#   {'youtube video commercial trailer': 0.23233071620292375}],
#  'Frame 103: 51.27 seconds': [{'Drake rapper music': 0.2081350792266176},
#   {'beyonce': 0.23485110962147118},
#   {'youtube video commercial trailer': 0.2263117087222718}],
#  'Frame 104: 51.76 seconds': [{'Drake rapper music': 0.21093055863434163},
#   {'beyonce': 0.27054321639907586},
#   {'youtube video commercial trailer': 0.22942654118722486}],
#  'Frame 105: 52.26 seconds': [{'Drake rapper music': 0.224172752203729},
#   {'youtube video commercial trailer': 0.2313417233563528}],
#  'Frame 106: 52.76 seconds': [{'Drake rapper music': 0.21105024330132255},
#   {'beyonce': 0.25532845231317436},
#   {'youtube video commercial trailer': 0.2351006638532387}],
#  'Frame 107: 53.26 seconds': [{'Drake rapper music': 0.2034972775138629},
#   {'beyonce': 0.26977306813655094},
#   {'youtube video commercial trailer': 0.22875157377309965}],
#  'Frame 108: 53.76 seconds': [{'Drake rapper music': 0.20978201303164054},
#   {'beyonce': 0.29089406266288537},
#   {'youtube video commercial trailer': 0.2153684411617282}],
#  'Frame 109: 54.25 seconds': [{'Drake rapper music': 0.21379862268803893},
#   {'beyonce': 0.29372302618650364},
#   {'youtube video commercial trailer': 0.22285560954498548}],
#  'Frame 110: 54.75 seconds': [{'beyonce': 0.29893871502817826},
#   {'youtube video commercial trailer': 0.2221665538126475}],
#  'Frame 111: 55.25 seconds': [{'beyonce': 0.23158623948497145},
#   {'youtube video commercial trailer': 0.24360304108359038}],
#  'Frame 112: 55.75 seconds': [{'beyonce': 0.22253530753405978},
#   {'youtube video commercial trailer': 0.23537095784872938}],
#  'Frame 113: 56.24 seconds': [{'beyonce': 0.21874153898307697},
#   {'youtube video commercial trailer': 0.2398288311424874}],
#  'Frame 114: 56.74 seconds': [{'Drake rapper music': 0.20879234428967633},
#   {'French Fries Mcdonalds': 0.20196459927963833},
#   {'youtube video commercial trailer': 0.22704724188597433}],
#  'Frame 115: 57.24 seconds': [{'French Fries Mcdonalds': 0.2088647016885843},
#   {'youtube video commercial trailer': 0.23892717156812437}],
#  'Frame 116: 57.74 seconds': [{'Drake rapper music': 0.21223054815504902},
#   {'French Fries Mcdonalds': 0.20542920251350508},
#   {'youtube video commercial trailer': 0.23000396296589515}],
#  'Frame 117: 58.24 seconds': [{'Drake rapper music': 0.22553230847062705},
#   {'French Fries Mcdonalds': 0.20912799845052107},
#   {'youtube video commercial trailer': 0.22953081481927393}],
#  'Frame 118: 58.73 seconds': [{'Drake rapper music': 0.20938937414000397},
#   {'beyonce': 0.2885448792799382},
#   {'youtube video commercial trailer': 0.22264925242314396}],
#  'Frame 119: 59.23 seconds': [{'beyonce': 0.2540218410482421},
#   {'youtube video commercial trailer': 0.26057405169052655}],
#  'Frame 120: 59.73 seconds': [{'Drake rapper music': 0.20806605131740308},
#   {'beyonce': 0.2834662641421399},
#   {'French Fries Mcdonalds': 0.20530231142790673},
#   {'youtube video commercial trailer': 0.21866504863964845}],
#  'Frame 121: 60.23 seconds': [{'action video game shooting xbox': 0.21239031631598745}],
#  'Frame 122: 60.72 seconds': [{'action video game shooting xbox': 0.21503217313166195}],
#  'Frame 123: 61.22 seconds': [{'action video game shooting xbox': 0.22010011901437654},
#   {'youtube video commercial trailer': 0.2294104307830752}],
#  'Frame 124: 61.72 seconds': [{'action video game shooting xbox': 0.20858383428909733},
#   {'youtube video commercial trailer': 0.2218953728882102}],
#  'Frame 125: 62.22 seconds': [{'action video game shooting xbox': 0.20264016298604323},
#   {'youtube video commercial trailer': 0.22949337474958503}],
#  'Frame 126: 62.71 seconds': [{'action video game shooting xbox': 0.19853895652398248},
#   {'youtube video commercial trailer': 0.22589626312197664}],
#  'Frame 127: 63.21 seconds': [{'action video game shooting xbox': 0.2027058138584742}],
#  'Frame 128: 63.71 seconds': [{'action video game shooting xbox': 0.20584246979384235}],
#  'Frame 129: 64.21 seconds': [{'youtube video commercial trailer': 0.2211829414891685}],
#  'Frame 130: 64.71 seconds': [],
#  'Frame 131: 65.20 seconds': [{'youtube video commercial trailer': 0.22113831896704358}],
#  'Frame 132: 65.70 seconds': [{'action video game shooting xbox': 0.21830046349321233}],
#  'Frame 133: 66.20 seconds': [{'action video game shooting xbox': 0.21568485092979256},
#   {'youtube video commercial trailer': 0.21289326311766243}],
#  'Frame 134: 66.70 seconds': [{'action video game shooting xbox': 0.21246700866534907},
#   {'youtube video commercial trailer': 0.2256782092584076}],
#  'Frame 135: 67.19 seconds': [{'action video game shooting xbox': 0.22099908371566404},
#   {'youtube video commercial trailer': 0.2296698853102171}],
#  'Frame 136: 67.69 seconds': [{'action video game shooting xbox': 0.20915676623917326},
#   {'youtube video commercial trailer': 0.22764001671406664}],
#  'Frame 137: 68.19 seconds': [{'action video game shooting xbox': 0.21233143744738261},
#   {'youtube video commercial trailer': 0.22537608543766088}],
#  'Frame 138: 68.69 seconds': [{'action video game shooting xbox': 0.2191005689284755}],
#  'Frame 139: 69.19 seconds': [],
#  'Frame 140: 69.68 seconds': [{'action video game shooting xbox': 0.21143273834353693},
#   {'youtube video commercial trailer': 0.22920834778039237}],
#  'Frame 141: 70.18 seconds': [{'marvel combic book hero': 0.21238945426256736},
#   {'youtube video commercial trailer': 0.228909859755176}],
#  'Frame 142: 70.68 seconds': [{'marvel combic book hero': 0.21098273691725128},
#   {'youtube video commercial trailer': 0.22626275923795158}],
#  'Frame 143: 71.18 seconds': [{'youtube video commercial trailer': 0.23604054591850504}],
#  'Frame 144: 71.67 seconds': [{'youtube video commercial trailer': 0.23018067053743016}],
#  'Frame 145: 72.17 seconds': [{'Drake rapper music': 0.19992365716759344},
#   {'youtube video commercial trailer': 0.23336456605642875}],
#  'Frame 146: 72.67 seconds': [{'Drake rapper music': 0.19029184398544616},
#   {'marvel combic book hero': 0.2044225498815658},
#   {'youtube video commercial trailer': 0.23519559832897827}],
#  'Frame 147: 73.17 seconds': [{'youtube video commercial trailer': 0.23328121333605328}],
#  'Frame 148: 73.67 seconds': [{'Drake rapper music': 0.2107885603626546},
#   {'youtube video commercial trailer': 0.2373713392972961}],
#  'Frame 149: 74.16 seconds': [{'Drake rapper music': 0.21400865056957094},
#   {'youtube video commercial trailer': 0.23592004858706395}],
#  'Frame 150: 74.66 seconds': [{'youtube video commercial trailer': 0.2410219940721473}],
#  'Frame 151: 75.16 seconds': [{'youtube video commercial trailer': 0.23893793080444148}],
#  'Frame 152: 75.66 seconds': [{'youtube video commercial trailer': 0.24065926232466145}],
#  'Frame 153: 76.15 seconds': [{'Drake rapper music': 0.19956429396424763},
#   {'youtube video commercial trailer': 0.23468039092640564}],
#  'Frame 154: 76.65 seconds': [{'action video game shooting xbox': 0.20642742453909424},
#   {'youtube video commercial trailer': 0.24451783350968448}],
#  'Frame 155: 77.15 seconds': [{'action video game shooting xbox': 0.2029637319386612},
#   {'youtube video commercial trailer': 0.2445428903129051}],
#  'Frame 156: 77.65 seconds': [{'action video game shooting xbox': 0.19484657302989225},
#   {'youtube video commercial trailer': 0.24416200022432943}],
#  'Frame 157: 78.14 seconds': [{'action video game shooting xbox': 0.18869837432900088},
#   {'youtube video commercial trailer': 0.248611413590948}],
#  'Frame 158: 78.64 seconds': [{'action video game shooting xbox': 0.19024792084132836},
#   {'youtube video commercial trailer': 0.2463841455557613}],
#  'Frame 159: 79.14 seconds': [{'Drake rapper music': 0.20912653330318812},
#   {'youtube video commercial trailer': 0.2340442882562562}],
#  'Frame 160: 79.64 seconds': [{'action video game shooting xbox': 0.19873025009577472},
#   {'Drake rapper music': 0.2068002147932686},
#   {'youtube video commercial trailer': 0.23034059407941518}],
#  'Frame 161: 80.14 seconds': [{'French Fries Mcdonalds': 0.2764838881657123},
#   {'youtube video commercial trailer': 0.25153040425961376}],
#  'Frame 162: 80.63 seconds': [{'French Fries Mcdonalds': 0.2800857538092443},
#   {'youtube video commercial trailer': 0.2479099720247283}],
#  'Frame 163: 81.13 seconds': [{'French Fries Mcdonalds': 0.2940121089574077}],
#  'Frame 164: 81.63 seconds': [{'French Fries Mcdonalds': 0.28581941383995246}],
#  'Frame 165: 82.13 seconds': [{'French Fries Mcdonalds': 0.2939315736917666}],
#  'Frame 166: 82.62 seconds': [{'French Fries Mcdonalds': 0.28764183689201545}],
#  'Frame 167: 83.12 seconds': [{'French Fries Mcdonalds': 0.29269123407819203}],
#  'Frame 168: 83.62 seconds': [{'French Fries Mcdonalds': 0.2968045270180526}],
#  'Frame 169: 84.12 seconds': [{'French Fries Mcdonalds': 0.30112114755950475}],
#  'Frame 170: 84.62 seconds': [{'beyonce': 0.21483220750001977},
#   {'French Fries Mcdonalds': 0.27059579854907073},
#   {'youtube video commercial trailer': 0.24881889547014444}],
#  'Frame 171: 85.11 seconds': [{'beyonce': 0.22448236864878626},
#   {'French Fries Mcdonalds': 0.27168862268363553},
#   {'youtube video commercial trailer': 0.25560101436309207}],
#  'Frame 172: 85.61 seconds': [{'beyonce': 0.21879529377111054},
#   {'French Fries Mcdonalds': 0.28058087874937176},
#   {'youtube video commercial trailer': 0.2481793806012738}],
#  'Frame 173: 86.11 seconds': [{'French Fries Mcdonalds': 0.281475302316498}],
#  'Frame 174: 86.61 seconds': [{'French Fries Mcdonalds': 0.2820099673346775},
#   {'youtube video commercial trailer': 0.25258795470229956}],
#  'Frame 175: 87.10 seconds': [{'French Fries Mcdonalds': 0.22178479491324368}],
#  'Frame 176: 87.60 seconds': [{'action video game shooting xbox': 0.2452864997436948},
#   {'youtube video commercial trailer': 0.24893915020307145}],
#  'Frame 177: 88.10 seconds': [{'French Fries Mcdonalds': 0.2693613258543479},
#   {'youtube video commercial trailer': 0.24243951993909454}],
#  'Frame 178: 88.60 seconds': [{'French Fries Mcdonalds': 0.26470944453906387},
#   {'youtube video commercial trailer': 0.24169538597010576}],
#  'Frame 179: 89.10 seconds': [{'French Fries Mcdonalds': 0.26259184032265265}],
#  'Frame 180: 89.59 seconds': [{'French Fries Mcdonalds': 0.25909688249071516},
#   {'youtube video commercial trailer': 0.23588685694359177}],
#  'Frame 181: 90.09 seconds': [{'action video game shooting xbox': 0.22976359631465662},
#   {'youtube video commercial trailer': 0.24044201564830195}],
#  'Frame 182: 90.59 seconds': [{'action video game shooting xbox': 0.22237509988584653},
#   {'youtube video commercial trailer': 0.24105376120534547}],
#  'Frame 183: 91.09 seconds': [{'action video game shooting xbox': 0.2148820215663356},
#   {'youtube video commercial trailer': 0.23058722726053396}],
#  'Frame 184: 91.58 seconds': [{'action video game shooting xbox': 0.2405634428176347},
#   {'youtube video commercial trailer': 0.22844992331376035}],
#  'Frame 185: 92.08 seconds': [{'youtube video commercial trailer': 0.22405599831743006}],
#  'Frame 186: 92.58 seconds': [{'youtube video commercial trailer': 0.2346346606103727}],
#  'Frame 187: 93.08 seconds': [{'youtube video commercial trailer': 0.22365211427216}],
#  'Frame 188: 93.57 seconds': [{'youtube video commercial trailer': 0.23501793303278415}],
#  'Frame 189: 94.07 seconds': [{'youtube video commercial trailer': 0.23450037764436776}],
#  'Frame 190: 94.57 seconds': [{'youtube video commercial trailer': 0.22727735838282426}],
#  'Frame 191: 95.07 seconds': [{'youtube video commercial trailer': 0.22660585084366808}],
#  'Frame 192: 95.57 seconds': [{'youtube video commercial trailer': 0.23230620644081038}],
#  'Frame 193: 96.06 seconds': [{'Drake rapper music': 0.21235793192222444},
#   {'beyonce': 0.20421402003369937},
#   {'youtube video commercial trailer': 0.2168348958046227},
#   {'church holy cross': 0.20070012989904532}],
#  'Frame 194: 96.56 seconds': [{'youtube video commercial trailer': 0.22167208355516377}],
#  'Frame 195: 97.06 seconds': [{'youtube video commercial trailer': 0.2156496602486677}],
#  'Frame 196: 97.56 seconds': [{'youtube video commercial trailer': 0.2206153490575009},
#   {'church holy cross': 0.19448746318829263}],
#  'Frame 197: 98.05 seconds': [{'youtube video commercial trailer': 0.2133019338645942},
#   {'church holy cross': 0.19546616671916442}],
#  'Frame 198: 98.55 seconds': [{'youtube video commercial trailer': 0.22044678850973837}],
#  'Frame 199: 99.05 seconds': [{'beyonce': 0.2004693131925882},
#   {'youtube video commercial trailer': 0.2143771061007307},
#   {'church holy cross': 0.19836126419751782}],
#  'Frame 200: 99.55 seconds': [{'youtube video commercial trailer': 0.2180349001958274},
#   {'church holy cross': 0.19726880960891413}],
#  'Frame 201: 100.05 seconds': [{'action video game shooting xbox': 0.1995814126094469},
#   {'youtube video commercial trailer': 0.23940448043844528}],
#  'Frame 202: 100.54 seconds': [{'action video game shooting xbox': 0.19859036210119566},
#   {'youtube video commercial trailer': 0.240980352034695}],
#  'Frame 203: 101.04 seconds': [{'action video game shooting xbox': 0.2628483810898111},
#   {'youtube video commercial trailer': 0.25130684018356586}],
#  'Frame 204: 101.54 seconds': [{'action video game shooting xbox': 0.23458333117272973},
#   {'youtube video commercial trailer': 0.24505621220454749}],
#  'Frame 205: 102.04 seconds': [{'action video game shooting xbox': 0.23935962126615928},
#   {'youtube video commercial trailer': 0.26871766513458173}],
#  'Frame 206: 102.53 seconds': [{'youtube video commercial trailer': 0.25442905981636177}],
#  'Frame 207: 103.03 seconds': [{'youtube video commercial trailer': 0.25274363728084703}],
#  'Frame 208: 103.53 seconds': [],
#  'Frame 209: 104.03 seconds': [{'youtube video commercial trailer': 0.24475694752537844}],
#  'Frame 210: 104.52 seconds': [{'youtube video commercial trailer': 0.2509860730618429}],
#  'Frame 211: 105.02 seconds': [{'youtube video commercial trailer': 0.2361193372202271}],
#  'Frame 212: 105.52 seconds': [{'action video game shooting xbox': 0.22913793438946287},
#   {'Drake rapper music': 0.24179143022512353},
#   {'youtube video commercial trailer': 0.2542296785647023}],
#  'Frame 213: 106.02 seconds': [{'action video game shooting xbox': 0.22845751248702356},
#   {'Drake rapper music': 0.22747628117707827},
#   {'youtube video commercial trailer': 0.24736305991049368}],
#  'Frame 214: 106.52 seconds': [{'action video game shooting xbox': 0.2375638489942798},
#   {'Drake rapper music': 0.22261881567124353},
#   {'youtube video commercial trailer': 0.24930970911647093}],
#  'Frame 215: 107.01 seconds': [],
#  'Frame 216: 107.51 seconds': [],
#  'Frame 217: 108.01 seconds': [{'youtube video commercial trailer': 0.2570667018847133}],
#  'Frame 218: 108.51 seconds': [{'youtube video commercial trailer': 0.25385820376701806}],
#  'Frame 219: 109.00 seconds': [{'youtube video commercial trailer': 0.25435714562613376}],
#  'Frame 220: 109.50 seconds': [{'action video game shooting xbox': 0.2429548346688782},
#   {'youtube video commercial trailer': 0.26701643138920733}]}

# %%
# Flatten the nested dictionary
data = frame_dict
# Define the threshold
threshold = 0.27

# Filter out key-value pairs below the threshold for each frame
filtered_data = [
    {
        frame: [
            {key: value}
            for item in items
            for key, value in item.items()
            if value > threshold
        ]
    }
    for frame, items in data.items()
]

print(filtered_data)
# Out:
# [{'Frame 0: 0.00 seconds': []}, {'Frame 1: 0.50 seconds': []}, {'Frame 2: 1.00 seconds': []}, {'Frame 3: 1.49 seconds': []}, {'Frame 4: 1.99 seconds': []}, {'Frame 5: 2.49 seconds': []}, {'Frame 6: 2.99 seconds': []}, {'Frame 7: 3.48 seconds': []}, {'Frame 8: 3.98 seconds': []}, {'Frame 9: 4.48 seconds': [{'action video game shooting xbox': 0.28382190441216126}]}, {'Frame 10: 4.98 seconds': []}, {'Frame 11: 5.48 seconds': [{'action video game shooting xbox': 0.2857121689011761}]}, {'Frame 12: 5.97 seconds': []}, {'Frame 13: 6.47 seconds': [{'action video game shooting xbox': 0.2838515535424833}]}, {'Frame 14: 6.97 seconds': []}, {'Frame 15: 7.47 seconds': []}, {'Frame 16: 7.96 seconds': []}, {'Frame 17: 8.46 seconds': []}, {'Frame 18: 8.96 seconds': []}, {'Frame 19: 9.46 seconds': []}, {'Frame 20: 9.95 seconds': []}, {'Frame 21: 10.45 seconds': [{'Drake rapper music': 0.2852440045098531}]}, {'Frame 22: 10.95 seconds': [{'Drake rapper music': 0.2986185267688645}]}, {'Frame 23: 11.45 seconds': [{'Drake rapper music': 0.30189190534092464}]}, {'Frame 24: 11.95 seconds': [{'Drake rapper music': 0.2832604035400707}]}, {'Frame 25: 12.44 seconds': [{'Drake rapper music': 0.29112512830049314}]}, {'Frame 26: 12.94 seconds': [{'Drake rapper music': 0.28955762280866304}]}, {'Frame 27: 13.44 seconds': []}, {'Frame 28: 13.94 seconds': []}, {'Frame 29: 14.43 seconds': []}, {'Frame 30: 14.93 seconds': [{'Drake rapper music': 0.3045701130595081}]}, {'Frame 31: 15.43 seconds': [{'Drake rapper music': 0.30078897464226373}]}, {'Frame 32: 15.93 seconds': [{'Drake rapper music': 0.2896128508728653}]}, {'Frame 33: 16.43 seconds': [{'Drake rapper music': 0.29701714781282174}]}, {'Frame 34: 16.92 seconds': []}, {'Frame 35: 17.42 seconds': []}, {'Frame 36: 17.92 seconds': [{'Drake rapper music': 0.3014483446408932}]}, {'Frame 37: 18.42 seconds': [{'Drake rapper music': 0.28886610456942907}]}, {'Frame 38: 18.91 seconds': [{'Drake rapper music': 0.29264808695741784}]}, {'Frame 39: 19.41 seconds': [{'Drake rapper music': 0.28984402165117185}]}, {'Frame 40: 19.91 seconds': [{'Drake rapper music': 0.2888288281006909}]}, {'Frame 41: 20.41 seconds': []}, {'Frame 42: 20.90 seconds': []}, {'Frame 43: 21.40 seconds': []}, {'Frame 44: 21.90 seconds': []}, {'Frame 45: 22.40 seconds': []}, {'Frame 46: 22.90 seconds': []}, {'Frame 47: 23.39 seconds': []}, {'Frame 48: 23.89 seconds': []}, {'Frame 49: 24.39 seconds': []}, {'Frame 50: 24.89 seconds': []}, {'Frame 51: 25.38 seconds': []}, {'Frame 52: 25.88 seconds': []}, {'Frame 53: 26.38 seconds': []}, {'Frame 54: 26.88 seconds': []}, {'Frame 55: 27.38 seconds': []}, {'Frame 56: 27.87 seconds': []}, {'Frame 57: 28.37 seconds': []}, {'Frame 58: 28.87 seconds': []}, {'Frame 59: 29.37 seconds': []}, {'Frame 60: 29.86 seconds': []}, {'Frame 61: 30.36 seconds': []}, {'Frame 62: 30.86 seconds': []}, {'Frame 63: 31.36 seconds': []}, {'Frame 64: 31.86 seconds': []}, {'Frame 65: 32.35 seconds': []}, {'Frame 66: 32.85 seconds': []}, {'Frame 67: 33.35 seconds': []}, {'Frame 68: 33.85 seconds': []}, {'Frame 69: 34.34 seconds': []}, {'Frame 70: 34.84 seconds': []}, {'Frame 71: 35.34 seconds': []}, {'Frame 72: 35.84 seconds': []}, {'Frame 73: 36.33 seconds': []}, {'Frame 74: 36.83 seconds': []}, {'Frame 75: 37.33 seconds': []}, {'Frame 76: 37.83 seconds': []}, {'Frame 77: 38.33 seconds': []}, {'Frame 78: 38.82 seconds': []}, {'Frame 79: 39.32 seconds': []}, {'Frame 80: 39.82 seconds': []}, {'Frame 81: 40.32 seconds': []}, {'Frame 82: 40.81 seconds': []}, {'Frame 83: 41.31 seconds': []}, {'Frame 84: 41.81 seconds': []}, {'Frame 85: 42.31 seconds': []}, {'Frame 86: 42.81 seconds': []}, {'Frame 87: 43.30 seconds': []}, {'Frame 88: 43.80 seconds': []}, {'Frame 89: 44.30 seconds': []}, {'Frame 90: 44.80 seconds': []}, {'Frame 91: 45.29 seconds': []}, {'Frame 92: 45.79 seconds': []}, {'Frame 93: 46.29 seconds': []}, {'Frame 94: 46.79 seconds': []}, {'Frame 95: 47.29 seconds': []}, {'Frame 96: 47.78 seconds': []}, {'Frame 97: 48.28 seconds ...

# %%
# Specify the filename for the JSON file
filename = 'telly_clip.json'

# Write the dictionary to the JSON file
with open(filename, 'w') as json_file:
    json.dump(filtered_data, json_file, indent=4)  # The indent parameter is optional for pretty-printing

#print(f'Data has been written to {filename})

# %%
# Flatten the data
flat_data = []
for _dict in filtered_data:
    frame_name, items = next(iter(_dict.items()))
    item_dict = next(iter(items))
    key, value = next(iter(item_dict.items()))
    flat_data.append({'Frame': frame_name, 'Key': key, 'Value': value})

# Create a DataFrame
ogdf = pd.DataFrame(flat_data)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[248], line 5
#       3 for _dict in filtered_data:
#       4     frame_name, items = next(iter(_dict.items()))
# ----> 5     item_dict = next(iter(items))
#       6     key, value = next(iter(item_dict.items()))
#       7     flat_data.append({'Frame': frame_name, 'Key': key, 'Value': value})
#
# StopIteration:

# %%
len(filtered_data)
# Out:
# 221

# %%
ogdf = make_df(filtered_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[240], line 1
# ----> 1 ogdf = make_df(filtered_data)
#
# Cell In[70], line 12, in make_df(frame_dict)
#       9 values_column = []
#      11 # Loop through the dictionary and populate the columns
# ---> 12 for frame, values in data.items():
#      13     frame_column.append(frame)
#      14     # Convert dictionaries to a comma-separated string representation
#
# AttributeError: 'list' object has no attribute 'items'

# %%
final_dict = frame_dict

# %%
final_dict

# %%
# Specify the filename for the JSON file
filename = 'final_dict.json'

# Write the dictionary to the JSON file
with open(filename, 'w') as json_file:
    json.dump(frame_dict, json_file, indent=4)  # The indent parameter is optional for pretty-printing

print(f'Data has been written to {filename}')# The indent parameter is optional for pretty-printing
# Out:
# Data has been written to final_dict.json

# %%
dff2 = make_df(frame_dict)

# %%
dff2.head()
# Out:
#                    Frame                                             Values
# 0  Frame 0: 0.00 seconds  {'action video game shooting xbox': 0.25154427...
# 1  Frame 1: 0.50 seconds  {'action video game shooting xbox': 0.25678583...
# 2  Frame 2: 1.00 seconds  {'action video game shooting xbox': 0.26493082...
# 3  Frame 3: 1.49 seconds  {'action video game shooting xbox': 0.26455160...
# 4  Frame 4: 1.99 seconds  {'action video game shooting xbox': 0.26202807...

# %%
data = {'action video game shooting xbox': 0.2620280756204121}, {'youtube video commercial trailer': 0.2330172919859395}

def filter_dict(data_dict, threshold):
    data_dict = list(data_dict)
    print(data_dict)
    filtered_dict = {key: value for entry in data_dict for key, value in entry.items() if value > threshold}
    return filtered_dict

filtered_data = filter_dict(data, 0.26)
print(filtered_data)
# Out:
# [{'action video game shooting xbox': 0.2620280756204121}, {'youtube video commercial trailer': 0.2330172919859395}]
# {'action video game shooting xbox': 0.2620280756204121}

# %%
datadf = dff2

# %%
import json

# Sample string

# Using json.loads to convert the string into a dictionary

def filter_dict2(data_dict, threshold):
    data_dict = [data_dict]
    data_dict = str(data_dict[0])
    data_dict = json.loads(data_dict.replace("'", "\""))
    threshold = 0.2

    filtered_data_list = [item for item in data_dict if next(iter(item.values())) > threshold]

    
    return filtered_data_list

# %%
data_df['Values_filtered'] = data_df['Values'].apply(lambda x: filter_dict2(x, threshold))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 data_df['Values_filtered'] = data_df['Values'].apply(lambda x: filter_dict2(x, threshold))
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[235], line 1, in <lambda>(x)
# ----> 1 data_df['Values_filtered'] = data_df['Values'].apply(lambda x: filter_dict2(x, threshold))
#
# Cell In[234], line 13, in filter_dict2(data_dict, threshold)
#      10 data_dict = json.loads(data_dict.replace("'", "\""))
#      11 threshold = 0.2
# ---> 13 filtered_data_list = [item for item in data_dict if next(iter(item.values())) > threshold]
#      16 return filtered_data_list
#
# Cell In[234], line 13, in <listcomp>(.0)
#      10 data_dict = json.loads(data_dict.replace("'", "\""))
#      11 threshold = 0.2
# ---> 13 filtered_data_list = [item for item in data_dict if next(iter(item.values())) > threshold]
#      16 return filtered_data_list
#
# AttributeError: 'str' object has no attribute 'values'

# %%
data_df
# Out:
#                          Frame  \
# 0        Frame 0: 0.00 seconds
# 1        Frame 1: 0.50 seconds
# 2        Frame 2: 1.00 seconds
# 3        Frame 3: 1.49 seconds
# 4        Frame 4: 1.99 seconds
# ..                         ...
# 216  Frame 216: 107.51 seconds
# 217  Frame 217: 108.01 seconds
# 218  Frame 218: 108.51 seconds
# 219  Frame 219: 109.00 seconds
# 220  Frame 220: 109.50 seconds
#
#                                                 Values Values_filtered
# 0    {'action video game shooting xbox': 0.25154427...   <class 'str'>
# 1    {'action video game shooting xbox': 0.25678583...   <class 'str'>
# 2    {'action video game shooting xbox': 0.26493082...   <class 'str'>
# 3    {'action video game shooting xbox': 0.26455160...   <class 'str'>
# 4    {'action video game shooting xbox': 0.26202807...   <class 'str'>
# ..                                                 ...             ...
# 216                                                      <class 'str'>
# 217  {'youtube video commercial trailer': 0.2570667...   <class 'str'>
# 218  {'youtube video commercial trailer': 0.2538582...   <class 'str'>
# 219  {'youtube video commercial trailer': 0.2543571...   <class 'str'>
# 220  {'action video game shooting xbox': 0.24295483...   <class 'str'>
#
# [221 rows x 3 columns]

# %%
filtered_data
# Out:
# {'Drake rapper music': 0.2852440045098531,
#  'youtube video commercial trailer': 0.24491280174877503}

# %% [markdown]
# ## extra

# %%
dff
# Out:
#                          Frame  \
# 0        Frame 0: 0.00 seconds
# 1        Frame 1: 0.50 seconds
# 2        Frame 2: 1.00 seconds
# 3        Frame 3: 1.49 seconds
# 4        Frame 4: 1.99 seconds
# ..                         ...
# 216  Frame 216: 107.51 seconds
# 217  Frame 217: 108.01 seconds
# 218  Frame 218: 108.51 seconds
# 219  Frame 219: 109.00 seconds
# 220  Frame 220: 109.50 seconds
#
#                                                 Values
# 0    {'action video game shooting xbox': 0.25154427...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 216
# 217
# 218
# 219
# 220
#
# [221 rows x 2 columns]

# %%
frame_dict
# Out:
# {'Frame 0: 0.00 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 1: 0.50 seconds': ['action video game shooting xbox',
#   'Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 2: 1.00 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 3: 1.49 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating',
#   'Church religion holy cross'],
#  'Frame 4: 1.99 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating'],
#  'Frame 5: 2.49 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 6: 2.99 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 7: 3.48 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 8: 3.98 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 9: 4.48 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 10: 4.98 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 11: 5.48 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 12: 5.97 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 13: 6.47 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 14: 6.97 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 15: 7.47 seconds': ['action video game shooting xbox',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 16: 7.96 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Church religion holy cross'],
#  'Frame 17: 8.46 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Church religion holy cross',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 18: 8.96 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Church religion holy cross'],
#  'Frame 19: 9.46 seconds': ['action video game shooting xbox',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Church religion holy cross'],
#  'Frame 20: 9.95 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Church religion holy cross',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 21: 10.45 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 22: 10.95 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'beyonce the singer video'],
#  'Frame 23: 11.45 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 24: 11.95 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 25: 12.44 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 26: 12.94 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 27: 13.44 seconds': ['action video game shooting xbox',
#   'Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 28: 13.94 seconds': ['action video game shooting xbox',
#   'Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 29: 14.43 seconds': ['action video game shooting xbox',
#   'Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 30: 14.93 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 31: 15.43 seconds': ['Drake the rapper',
#   'music video singing dancing'],
#  'Frame 32: 15.93 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video'],
#  'Frame 33: 16.43 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video'],
#  'Frame 34: 16.92 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating'],
#  'Frame 35: 17.42 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating'],
#  'Frame 36: 17.92 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 37: 18.42 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 38: 18.91 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 39: 19.41 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Mcdonalds Fast Food Fries people eating',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 40: 19.91 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 41: 20.41 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 42: 20.90 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 43: 21.40 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 44: 21.90 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'soccer game soccer ball grass',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 45: 22.40 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 46: 22.90 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 47: 23.39 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 48: 23.89 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 49: 24.39 seconds': ['music video singing dancing',
#   'flower picnic people',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 50: 24.89 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'flower picnic people',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 51: 25.38 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video',
#   'Pete Davidson Mr. Beast Celebrity'],
#  'Frame 52: 25.88 seconds': ['music video singing dancing',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 53: 26.38 seconds': ['Drake the rapper',
#   'music video singing dancing',
#   'flower picnic people',
#   'superhero action film video',
#   'beyonce the singer video'],
#  'Frame 54: 26.88 seconds': ['music video singing dancing',
#   'flower picnic people',
#   'superhero action film video']}

# %%
#prompt tweaking
#similarity threshold
#frequency

# %%
#print(os.path.exists(VIDEO))
import time
total_frames = 160
total_seconds = 110
stride_length = 30
frames_per_second = total_frames / total_seconds
frame_dict = {}
max_retries = 3
#print(os.path.exists(VIDEO))

num_frames = 0
for frame_index,frame in enumerate(sv.get_video_frames_generator(source_path=VIDEO,stride=stride_length,start =0)):
    frame_second = frame_index * (1 / frames_per_second)
    frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"] = []
    #if frame_index < 30:
    print(f"Frame {frame_index}: {frame_second:.2f} seconds")
    retries = 0
    for prompt in prompt_list:
        retries = 0
        while retries < max_retries:
            try:
                label = classify_image(frame)
                if label == prompt[0]:
                    print('Label found')
                    frame_dict[f"Frame {frame_index}: {frame_second:.2f} seconds"].append(label)
                    print('\n')
                break  # Break the retry loop if successful
            except Exception as e:
                print(f"Error: {e}")
                print(f"Retrying... (Attempt {retries + 1}/{max_retries})")
                retries += 1
                time.sleep(1)  # Wait for a short period before retrying
print(num_frames)
# Out:
# Frame 0: 0.00 seconds
# Frame 1: 0.69 seconds
# Frame 2: 1.38 seconds
# Frame 3: 2.06 seconds
# Frame 4: 2.75 seconds
# Frame 5: 3.44 seconds
# Frame 6: 4.12 seconds
# Frame 7: 4.81 seconds
# Frame 8: 5.50 seconds
# Frame 9: 6.19 seconds
# Frame 10: 6.88 seconds
# Frame 11: 7.56 seconds
# Frame 12: 8.25 seconds
# Frame 13: 8.94 seconds
# Frame 14: 9.62 seconds
# Frame 15: 10.31 seconds
# Frame 16: 11.00 seconds
# Frame 17: 11.69 seconds
# Frame 18: 12.38 seconds
# Frame 19: 13.06 seconds
# Frame 20: 13.75 seconds
# Frame 21: 14.44 seconds
# Frame 22: 15.12 seconds
# Frame 23: 15.81 seconds
# Frame 24: 16.50 seconds
# Frame 25: 17.19 seconds
# Frame 26: 17.88 seconds
# Frame 27: 18.56 seconds
# Frame 28: 19.25 seconds
# Frame 29: 19.94 seconds
# Frame 30: 20.62 seconds
# Frame 31: 21.31 seconds
# Frame 32: 22.00 seconds
# Frame 33: 22.69 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 22
#      20 while retries < max_retries:
#      21     try:
# ---> 22         label = classify_image(frame)
#      23         if label == prompt[0]:
#      24             print('Label found')
#
# Cell In[26], line 18, in classify_image(image)
#       7 image_data = base64.b64encode(buffer.getvalue()).decode("utf-8")
#       9 payload = {
#      10     "api_key": API_KEY,
#      11     "subject": {
#    (...)
#      15     "prompt": prompt,
#      16 }
# ---> 18 data = requests.post(INFERENCE_ENDPOINT + "/clip/compare?api_key=" + API_KEY, json=payload)
#      20 response = data.json()
#      21 #print(response["similarity"])
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/magic/lib/python3.8/site-packages/urllib3/connection.py:454, in HTTPConnection.getresponse(self)
#     451 from .response import HTTPResponse
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#     457     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/magic/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/anaconda3/envs/magic/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/anaconda3/envs/magic/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/magic/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/anaconda3/envs/magic/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/magic/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
# Create an empty dataframe
data = frame_dict

# Create lists for columns
frame_column = []
values_column = []

# Loop through the dictionary and populate the columns
for frame, values in data.items():
    frame_column.append(frame)
    values_column.append(', '.join(values))

# Create the dataframe
df = pd.DataFrame({'Frame': frame_column, 'Values': values_column})

df.to_csv('all_frames_similarity.csv')

# %%
prompts = ["action video game","not action video game"]

# %%
prompts = ["action video game","not action video game"]
active_prompt_list = ["shooting"]
#CLASS_MAP_gun = ["gun","no_gun"]

# %%
for in range

# %%
frame_category
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
_list = ['action video game',"not action video game"]

# %%
frame_intervals = list(range(20, 280, 20))
frame_category = list(range(10,110,10))
results = []
stride_length = 30
frame_index = 0
#print(os.path.exists(VIDEO))
num_frames = 0
for frame in enumerate(sv.get_video_frames_generator(source_path=VIDEO,stride=stride_length,start =0)):
    #label = classify_image(frame)
    num_frames +=1
    if num_frames % 20 == 0:
        #print(num_frames)
        #print(frame_category[frame_index])
        #print(frame_intervals[frame_index])
        print('\n')
        #frame_index+=1
      
    
print(num_frames)
# Out:
# 28it [00:00, 40.61it/s]
# 45it [00:01, 44.40it/s]
# 64it [00:01, 35.92it/s]
# 88it [00:02, 42.43it/s]
# 104it [00:02, 46.95it/s]
# 128it [00:03, 39.80it/s]
# 150it [00:03, 48.17it/s]
# 165it [00:04, 54.17it/s]
# 188it [00:04, 47.75it/s]
# 204it [00:04, 44.80it/s]
# 221it [00:06, 36.28it/s]
# 221

# %%
#prompt list of 10. if it gets it, add it to list, and also which frame

# %%
prompts = ["Drake","random person"]
#active_prompt_list = ["shooting"]

# %%
results = []
stride_length = 30
#print(os.path.exists(VIDEO))

num_frames = 0
for frame in tqdm(sv.get_video_frames_generator(source_path=VIDEO,stride=stride_length)):
    
    num_frames+=1
    #print(num_frames)

    if num_frames >20 and num_frames < 45:
        print(num_frames)
        label = classify_image(frame)
        print(label)
      
        if label == prompts[0]:
            print(label)
            print('LABEL FOUND')
    elif num_frames > 45:
        break
            
    

    #results.append(label)
    #if num_frames < 100:
    #    break
    
video_length = stride_length * num_frames
video_length = video_length / 60
print(num_frames)
print(video_length)
# Out:
# 18it [00:00, 32.04it/s]
# 21
# [0.21278525563116968, 0.2276793166656769]
# random person
# 22
# 22it [00:01,  7.86it/s]
# [0.28315378839524374, 0.21910644315955138]
# Drake
# Drake
# LABEL FOUND
# 23
# [0.29448649617632927, 0.20471081431448296]
# Drake
# Drake
# LABEL FOUND
# 24
# [0.2992157873011149, 0.2094470267628897]
# Drake
# Drake
# LABEL FOUND
# 25
# 25it [00:03,  4.12it/s]
# [0.2833458253830297, 0.20780658053403403]
# Drake
# Drake
# LABEL FOUND
# 26
# [0.2913344143270633, 0.2080881761309545]
# Drake
# Drake
# LABEL FOUND
# 27
# 27it [00:04,  3.42it/s]
# [0.2919890919500771, 0.19950343714508936]
# Drake
# Drake
# LABEL FOUND
# 28
# [0.23505412146691754, 0.1927602175575251]
# Drake
# Drake
# LABEL FOUND
# 29
# 29it [00:05,  2.80it/s]
# [0.23679538994858787, 0.19367486559685332]
# Drake
# Drake
# LABEL FOUND
# 30
# 30it [00:06,  2.63it/s]
# [0.27504372055707405, 0.23258823833517972]
# Drake
# Drake
# LABEL FOUND
# 31
# 31it [00:06,  2.35it/s]
# [0.2990253635416379, 0.20871301220336244]
# Drake
# Drake
# LABEL FOUND
# 32
# 32it [00:07,  2.28it/s]
# [0.29776158542736825, 0.21735953040512462]
# Drake
# Drake
# LABEL FOUND
# 33
# 33it [00:07,  2.21it/s]
# [0.2855282864024514, 0.21475692070945027]
# Drake
# Drake
# LABEL FOUND
# 34
# 34it [00:08,  2.04it/s]
# [0.2942120824132894, 0.21834203578264808]
# Drake
# Drake
# LABEL FOUND
# 35
# 35it [00:08,  2.00it/s]
# [0.24045351577678786, 0.19133978491906684]
# Drake
# Drake
# LABEL FOUND
# 36
# 36it [00:09,  1.85it/s]
# [0.2414150095444465, 0.19092482868280977]
# Drake
# Drake
# LABEL FOUND
# 37
# 37it [00:10,  1.91it/s]
# [0.2990996180597319, 0.20405968198083194]
# Drake
# Drake
# LABEL FOUND
# 38
# 38it [00:10,  1.79it/s]
# [0.2824112305631857, 0.20555268214420758]
# Drake
# Drake
# LABEL FOUND
# 39
# 39it [00:11,  1.87it/s]
# [0.2819788148129171, 0.20643229623932657]
# Drake
# Drake
# LABEL FOUND
# 40
# 40it [00:11,  1.77it/s]
# [0.27954749907006987, 0.20727710241091546]
# Drake
# Drake
# LABEL FOUND
# 41
# 41it [00:12,  1.84it/s]
# [0.29461300162382986, 0.20825290506918495]
# Drake
# Drake
# LABEL FOUND
# 42
# 42it [00:12,  1.82it/s]
# [0.18508140260285572, 0.1975257288368981]
# random person
# 43
# 43it [00:13,  1.73it/s]
# [0.17575734612695573, 0.19933951008122627]
# random person
# 44
# 45it [00:14,  3.19it/s]
# [0.1895222855901908, 0.20003631163280605]
# random person
# 46
# 23.0

# %%
#stride of 30 = ~2 frames every second, so 20 frames every 10 seconds
#60 frames a second if 1:50 video, stride of 30, 221 frames,

# %%
prompts = ["picture of a gun","picture of no gun"]
active_prompt_list = ["picture of a gun"]
#CLASS_MAP_gun = ["gun","no_gun"]

# %%
from tqdm import tqdm

results = []

print(os.path.exists(VIDEO))
num_frames = 0
for frame in tqdm(sv.get_video_frames_generator(source_path=VIDEO, stride=10, start=0)):
    label = classify_image(frame)
    num_frames += 1
    results.append(label)

video_length = 10 * len(results)

video_length = video_length / 60

print(f"Does this video contain a {ACTIVE_PROMPT}?", "yes" if ACTIVE_PROMPT.lower() in results else "no")

print(num_frames)

if ACTIVE_PROMPT in results:
    print(f"When does the {ACTIVE_PROMPT} first appear?", round(results.index(ACTIVE_PROMPT) * 10 / 60, 0), "seconds")

print(f"For how long is the {ACTIVE_PROMPT} visible?", round(results.count(ACTIVE_PROMPT) * 10 / 60, 0), "seconds")
# Out:
# True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 7
#       5 print(os.path.exists(VIDEO))
#       6 num_frames = 0
# ----> 7 for frame in tqdm(sv.get_video_frames_generator(source_path=VIDEO, stride=10, start=0)):
#       8     label = classify_image(frame)
#       9     num_frames += 1
#
# AttributeError: module 'supervision' has no attribute 'get_video_frames_generator'

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.0
